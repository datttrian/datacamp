# %%
import pandas as pd

# %%
electric_cars_raw = pd.read_csv("https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD")
electric_cars_raw
# Out:
#         VIN (1-10)  ... 2020 Census Tract
# 0       KM8K33AGXL  ...      5.303300e+10
# 1       1C4RJYB61N  ...      5.303302e+10
# 2       1C4RJYD61P  ...      5.307700e+10
# 3       5YJ3E1EA7J  ...      5.303302e+10
# 4       WBY7Z8C5XJ  ...      5.306701e+10
# ...            ...  ...               ...
# 150477  WBY43AW05P  ...      5.302700e+10
# 150478  5YJ3E1EB7P  ...      5.303301e+10
# 150479  5YJYGDEEXM  ...      5.303301e+10
# 150480  5UXTA6C08P  ...      5.306105e+10
# 150481  7SAYGDEF8N  ...      5.305795e+10
#
# [150482 rows x 17 columns]

# %%
electric_cars = electric_cars_raw \
    [["City", "County", "Model Year", "Make", "Model", "Electric Vehicle Type"]] \
    .value_counts() \
    .reset_index() \
    .rename(columns={0: "n_cars"})
electric_cars.columns = electric_cars.columns \
    .str.lower() \
    .str.replace(" ", "_") \
    .values
electric_cars
# Out:
#            city  county  ...                   electric_vehicle_type n_cars
# 0       Seattle    King  ...          Battery Electric Vehicle (BEV)   1514
# 1       Seattle    King  ...          Battery Electric Vehicle (BEV)   1153
# 2       Seattle    King  ...          Battery Electric Vehicle (BEV)   1147
# 3       Seattle    King  ...          Battery Electric Vehicle (BEV)   1122
# 4      Bellevue    King  ...          Battery Electric Vehicle (BEV)    931
# ...         ...     ...  ...                                     ...    ...
# 26808  Lakewood  Pierce  ...          Battery Electric Vehicle (BEV)      1
# 26809  Lakewood  Pierce  ...  Plug-in Hybrid Electric Vehicle (PHEV)      1
# 26810  Lakewood  Pierce  ...          Battery Electric Vehicle (BEV)      1
# 26811  Lakewood  Pierce  ...          Battery Electric Vehicle (BEV)      1
# 26812    Zillah  Yakima  ...          Battery Electric Vehicle (BEV)      1
#
# [26813 rows x 7 columns]

# %%
electric_cars.to_csv("electric_cars.csv", index=False)
